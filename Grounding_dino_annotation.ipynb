# %%
# # Kaggle API 설치
# !pip install kaggle --upgrade

# # kaggle.json 업로드
# from google.colab import files
# uploaded = files.upload()

# # kaggle.json을 ~/.kaggle 폴더에 옮기기
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# # Kaggle 데이터 다운로드 예시
# !kaggle datasets download -d thepbordin/indoor-object-detection

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !sudo apt-get install -y p7zip-full
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# p7zip-full is already the newest version (16.02+dfsg-8).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
import os

# 압축 파일 경로와 출력 경로 지정
dataset_path = "/content/drive/MyDrive/modu/furniture_dataset.7z"
output_dir = "/content/output"

# 출력 디렉토리가 없으면 생성
os.makedirs(output_dir, exist_ok=True)

# 7z 파일 압축 해제
!7z x "{dataset_path}" -o"{output_dir}" -y

# 압축 해제된 파일 확인
print(os.listdir(output_dir))
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.00GHz (50653),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 2460097692 bytes (2347 MiB)
#
# Extracting archive: /content/drive/MyDrive/modu/furniture_dataset.7z
# WARNING:
# /content/drive/MyDrive/modu/furniture_dataset.7z
# Can not open the file as [7z] archive
# The file is open as [zip] archive
#
# --
# Path = /content/drive/MyDrive/modu/furniture_dataset.7z
# Open WARNING: Can not open the file as [7z] archive
# Type = zip
# Physical Size = 2460097692
# 64-bit = +
#
# Everything is Ok
#
# Archives with Warnings: 1
# Folders: 112
# Files: 90095
# Size:       2535060309
# Compressed: 2460097692
# ['Bonn_Furniture_Styles_Dataset']

# %% [markdown]
# # DINO

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# %cd {HOME}
# !git clone https://github.com/IDEA-Research/GroundingDINO.git
# %cd {HOME}/GroundingDINO
# !pip install -q -e .
# !pip install -q roboflow
# Out:
# /content
# Cloning into 'GroundingDINO'...
# remote: Enumerating objects: 463, done.
# remote: Counting objects: 100% (240/240), done.
# remote: Compressing objects: 100% (105/105), done.
# remote: Total 463 (delta 175), reused 135 (delta 135), pack-reused 223 (from 1)
# Receiving objects: 100% (463/463), 12.87 MiB | 16.54 MiB/s, done.
# Resolving deltas: 100% (241/241), done.
# /content/GroundingDINO
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 17.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.1 MB/s eta 0:00:00

# %%
import os

CONFIG_PATH = os.path.join(HOME, "GroundingDINO/groundingdino/config/GroundingDINO_SwinT_OGC.py")
print(CONFIG_PATH, "; exist:", os.path.isfile(CONFIG_PATH))
# Out:
# /content/GroundingDINO/groundingdino/config/GroundingDINO_SwinT_OGC.py ; exist: True

# %%
# %cd {HOME}
# !mkdir {HOME}/weights
# %cd {HOME}/weights

# !wget -q https://github.com/IDEA-Research/GroundingDINO/releases/download/v0.1.0-alpha/groundingdino_swint_ogc.pth
# Out:
# /content
# /content/weights

# %%
import os

WEIGHTS_NAME = "groundingdino_swint_ogc.pth"
WEIGHTS_PATH = os.path.join(HOME, "weights", WEIGHTS_NAME)
print(WEIGHTS_PATH, "; exist:", os.path.isfile(WEIGHTS_PATH))
# Out:
# /content/weights/groundingdino_swint_ogc.pth ; exist: True

# %%
# %cd {HOME}/GroundingDINO

from groundingdino.util.inference import load_model, load_image, predict, annotate

model = load_model(CONFIG_PATH, WEIGHTS_PATH)
# Out:
# /content/GroundingDINO
# FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
# UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3595.)
# final text_encoder_type: bert-base-uncased
# UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.

# %%
import os
import supervision as sv

IMAGE_NAME = "images.jpeg"
IMAGE_PATH = os.path.join(HOME, "/content/", IMAGE_NAME)

TEXT_PROMPT = "just one person"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25

# 클래스 이름 정의
class_names = ['person']

# Load image
image_source, image = load_image(IMAGE_PATH)

# Predict bounding boxes, logits, and phrases
boxes, logits, phrases = predict(
    model=model,
    image=image,
    caption=TEXT_PROMPT,
    box_threshold=BOX_TRESHOLD,
    text_threshold=TEXT_TRESHOLD
)

# Annotate the frame
annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)

# Plot annotated image
# %matplotlib inline
sv.plot_image(annotated_frame, (8, 8))

# Print bounding box information
print("\nDetected Objects:")
for i, box in enumerate(boxes):
    print(f"Object {i + 1}:")
    print(f"  Bounding Box: {box}")
    print(f"  Logits: {logits[i]}")
    print(f"  Phrase: {phrases[i]}")
# Out:
# Detected Objects:
# Object 1:
#   Bounding Box: tensor([0.2309, 0.6283, 0.1196, 0.7024])
#   Logits: 0.3943500518798828
#   Phrase: one person

# %%
import os
def yolo_to_txt(boxes, phrases, class_names):
    yolo_data = []
    for idx, box in enumerate(boxes):
        class_name = phrases[idx]
        class_id = class_names.index(class_name) if class_name in class_names else -1

        if class_id != -1:
            x_center, y_center, width, height = map(float, box)
            yolo_data.append(f"{class_id} {x_center:.6f} {y_center:.6f} {width:.6f} {height:.6f}")
    return yolo_data

# 이미지 처리 함수
def process_images(input_dir, output_dir, model, text_prompt, box_threshold, text_threshold, class_names):
    os.makedirs(output_dir, exist_ok=True)

    for root, _, files in os.walk(input_dir):
        for file_name in files:
            if file_name.lower().endswith(('.jpg', '.png', '.jpeg')):
                image_path = os.path.join(root, file_name)
                print(f"Processing {file_name}...")

                # 이미지 로드
                image_source, image = load_image(image_path)

                # Grounding DINO 모델로 예측
                boxes, logits, phrases = predict(
                    model=model,
                    image=image,
                    caption=text_prompt,
                    box_threshold=box_threshold,
                    text_threshold=text_threshold
                )

                # Grounding DINO의 YOLO 좌표와 라벨 그대로 사용
                yolo_output = yolo_to_txt(boxes, phrases, class_names)

                # YOLO 텍스트 파일 저장
                relative_path = os.path.relpath(root, input_dir)  # 하위 폴더 구조 유지
                output_subdir = os.path.join(output_dir, relative_path)
                os.makedirs(output_subdir, exist_ok=True)  # 출력 하위 폴더 생성

                txt_file_name = f"{os.path.splitext(file_name)[0]}.txt"
                txt_path = os.path.join(output_subdir, txt_file_name)
                with open(txt_path, "w") as txt_file:
                    txt_file.write("\n".join(yolo_output))
                print(f"Saved YOLO format text to: {txt_path}")

# 경로 설정
INPUT_DIR = "/content/output/Bonn_Furniture_Styles_Dataset/houzz/beds"
OUTPUT_DIR = "/content/output/beds"
TEXT_PROMPT = "bed"
BOX_THRESHOLD = 0.35
TEXT_THRESHOLD = 0.25

# 클래스 이름 정의
class_names = ['bed', 'chair', 'dresser', 'lamp', 'sofa', 'table']

# 실행
process_images(
    input_dir=INPUT_DIR,
    output_dir=OUTPUT_DIR,
    model=model,
    text_prompt=TEXT_PROMPT,
    box_threshold=BOX_THRESHOLD,
    text_threshold=TEXT_THRESHOLD,
    class_names=class_names
)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Saved YOLO format text to: /content/output/beds/Transitional/5192transitional-panel-beds.txt
# Processing 3471transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3471transitional-platform-beds.txt
# Processing 2655transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2655transitional-panel-beds.txt
# Processing 3420transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3420transitional-platform-beds.txt
# Processing 3360transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3360transitional-kids-beds.txt
# Processing 9711transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9711transitional-platform-beds.txt
# Processing 10211transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10211transitional-panel-beds.txt
# Processing 9975transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9975transitional-bunk-beds.txt
# Processing 2798transitional-kids-bedroom-furniture-sets.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2798transitional-kids-bedroom-furniture-sets.txt
# Processing 9585transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9585transitional-bunk-beds.txt
# Processing 9536transitional-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9536transitional-beds.txt
# Processing 5371transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/5371transitional-platform-beds.txt
# Processing 4981transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/4981transitional-kids-beds.txt
# Processing 5458transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/5458transitional-platform-beds.txt
# Processing 9363transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9363transitional-platform-beds.txt
# Processing 2556transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2556transitional-platform-beds.txt
# Processing 9342transitional-sleigh-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9342transitional-sleigh-beds.txt
# Processing 4353transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/4353transitional-kids-beds.txt
# Processing 3118transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3118transitional-panel-beds.txt
# Processing 4826transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/4826transitional-panel-beds.txt
# Processing 10247transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10247transitional-platform-beds.txt
# Processing 9456transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9456transitional-bunk-beds.txt
# Processing 10158transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10158transitional-platform-beds.txt
# Processing 7921transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/7921transitional-bunk-beds.txt
# Processing 9370transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9370transitional-bunk-beds.txt
# Processing 7654transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/7654transitional-bunk-beds.txt
# Processing 10125transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10125transitional-panel-beds.txt
# Processing 8517transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/8517transitional-kids-beds.txt
# Processing 9897transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9897transitional-bunk-beds.txt
# Processing 4921transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/4921transitional-panel-beds.txt
# Processing 9993transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9993transitional-platform-beds.txt
# Processing 2836transitional-daybeds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2836transitional-daybeds.txt
# Processing 2903transitional-kids-bedroom-furniture-sets.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2903transitional-kids-bedroom-furniture-sets.txt
# Processing 3139transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3139transitional-panel-beds.txt
# Processing 9556transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9556transitional-kids-beds.txt
# Processing 3700transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3700transitional-panel-beds.txt
# Processing 5395transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/5395transitional-panel-beds.txt
# Processing 9767transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9767transitional-panel-beds.txt
# Processing 9432transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9432transitional-panel-beds.txt
# Processing 3859transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3859transitional-platform-beds.txt
# Processing 7648transitional-sleigh-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/7648transitional-sleigh-beds.txt
# Processing 9618transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9618transitional-kids-beds.txt
# Processing 9534transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9534transitional-bunk-beds.txt
# Processing 8973transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/8973transitional-panel-beds.txt
# Processing 3055transitional-loft-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3055transitional-loft-beds.txt
# Processing 2610transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2610transitional-platform-beds.txt
# Processing 9414transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9414transitional-platform-beds.txt
# Processing 9317transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9317transitional-platform-beds.txt
# Processing 9821transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9821transitional-panel-beds.txt
# Processing 10192transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10192transitional-platform-beds.txt
# Processing 10273transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10273transitional-panel-beds.txt
# Processing 5100transitional-bedroom-furniture-sets.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/5100transitional-bedroom-furniture-sets.txt
# Processing 5326transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/5326transitional-platform-beds.txt
# Processing 9566transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9566transitional-bunk-beds.txt
# Processing 10304transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10304transitional-panel-beds.txt
# Processing 7924transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/7924transitional-panel-beds.txt
# Processing 7955transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/7955transitional-kids-beds.txt
# Processing 2864transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2864transitional-panel-beds.txt
# Processing 9936transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9936transitional-panel-beds.txt
# Processing 4019transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/4019transitional-platform-beds.txt
# Processing 2549transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2549transitional-platform-beds.txt
# Processing 9928transitional-daybeds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9928transitional-daybeds.txt
# Processing 9305transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9305transitional-panel-beds.txt
# Processing 9700transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9700transitional-bunk-beds.txt
# Processing 8050transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/8050transitional-panel-beds.txt
# Processing 4869transitional-daybeds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/4869transitional-daybeds.txt
# Processing 9272transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9272transitional-platform-beds.txt
# Processing 10132transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10132transitional-kids-beds.txt
# Processing 9934transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9934transitional-panel-beds.txt
# Processing 4115transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/4115transitional-platform-beds.txt
# Processing 7846transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/7846transitional-kids-beds.txt
# Processing 10196transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10196transitional-platform-beds.txt
# Processing 8509transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/8509transitional-kids-beds.txt
# Processing 9588transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9588transitional-bunk-beds.txt
# Processing 9504transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9504transitional-kids-beds.txt
# Processing 9433transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9433transitional-panel-beds.txt
# Processing 3042transitional-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3042transitional-beds.txt
# Processing 3323transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3323transitional-panel-beds.txt
# Processing 9987transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9987transitional-panel-beds.txt
# Processing 10051transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10051transitional-panel-beds.txt
# Processing 2929transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2929transitional-bunk-beds.txt
# Processing 9883transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9883transitional-panel-beds.txt
# Processing 9101transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9101transitional-panel-beds.txt
# Processing 9550transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9550transitional-kids-beds.txt
# Processing 2622transitional-daybeds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2622transitional-daybeds.txt
# Processing 9644transitional-kids-bedroom-furniture-sets.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9644transitional-kids-bedroom-furniture-sets.txt
# Processing 9275transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9275transitional-bunk-beds.txt
# Processing 5466transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/5466transitional-platform-beds.txt
# Processing 9241transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9241transitional-panel-beds.txt
# Processing 8124transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/8124transitional-bunk-beds.txt
# Processing 4856transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/4856transitional-platform-beds.txt
# Processing 7855transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/7855transitional-bunk-beds.txt
# Processing 10008transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10008transitional-panel-beds.txt
# Processing 10271transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10271transitional-panel-beds.txt
# Processing 9293transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9293transitional-bunk-beds.txt
# Processing 2624transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2624transitional-platform-beds.txt
# Processing 8743transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/8743transitional-panel-beds.txt
# Processing 3315transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3315transitional-platform-beds.txt
# Processing 9225transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9225transitional-bunk-beds.txt
# Processing 9280transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9280transitional-platform-beds.txt
# Processing 9294transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9294transitional-panel-beds.txt
# Processing 9980transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9980transitional-bunk-beds.txt
# Processing 7983transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/7983transitional-kids-beds.txt
# Processing 3835transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3835transitional-panel-beds.txt
# Processing 10327transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10327transitional-panel-beds.txt
# Processing 10142transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10142transitional-platform-beds.txt
# Processing 4877transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/4877transitional-platform-beds.txt
# Processing 2991transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2991transitional-bunk-beds.txt
# Processing 3245transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3245transitional-platform-beds.txt
# Processing 7510transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/7510transitional-platform-beds.txt
# Processing 9375transitional-daybeds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9375transitional-daybeds.txt
# Processing 3202transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3202transitional-panel-beds.txt
# Processing 4942transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/4942transitional-platform-beds.txt
# Processing 7647transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/7647transitional-kids-beds.txt
# Processing 5275transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/5275transitional-platform-beds.txt
# Processing 9739transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9739transitional-kids-beds.txt
# Processing 3275transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3275transitional-platform-beds.txt
# Processing 7838transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/7838transitional-bunk-beds.txt
# Processing 9379transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9379transitional-kids-beds.txt
# Processing 10275transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10275transitional-panel-beds.txt
# Processing 8494transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/8494transitional-bunk-beds.txt
# Processing 10138transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10138transitional-kids-beds.txt
# Processing 10045transitional-toddler-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10045transitional-toddler-beds.txt
# Processing 3448transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3448transitional-platform-beds.txt
# Processing 9813transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9813transitional-kids-beds.txt
# Processing 8039transitional-canopy-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/8039transitional-canopy-beds.txt
# Processing 5290transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/5290transitional-platform-beds.txt
# Processing 9593transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9593transitional-bunk-beds.txt
# Processing 5722transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/5722transitional-panel-beds.txt
# Processing 9442transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9442transitional-bunk-beds.txt
# Processing 3514transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3514transitional-platform-beds.txt
# Processing 10140transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10140transitional-kids-beds.txt
# Processing 4349transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/4349transitional-platform-beds.txt
# Processing 3925transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3925transitional-platform-beds.txt
# Processing 10297transitional-daybeds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10297transitional-daybeds.txt
# Processing 9154transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9154transitional-kids-beds.txt
# Processing 9823transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9823transitional-platform-beds.txt
# Processing 9636transitional-kids-bedroom-furniture-sets.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9636transitional-kids-bedroom-furniture-sets.txt
# Processing 9623transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9623transitional-kids-beds.txt
# Processing 10306transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10306transitional-panel-beds.txt
# Processing 9888transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9888transitional-panel-beds.txt
# Processing 10063transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10063transitional-platform-beds.txt
# Processing 3028transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3028transitional-kids-beds.txt
# Processing 9440transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9440transitional-panel-beds.txt
# Processing 9417transitional-daybeds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9417transitional-daybeds.txt
# Processing 3068transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3068transitional-kids-beds.txt
# Processing 3440transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3440transitional-panel-beds.txt
# Processing 4875transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/4875transitional-platform-beds.txt
# Processing 2707transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2707transitional-platform-beds.txt
# Processing 8093transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/8093transitional-panel-beds.txt
# Processing 9688transitional-adjustable-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9688transitional-adjustable-beds.txt
# Processing 9383transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9383transitional-panel-beds.txt
# Processing 2890transitional-sleigh-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2890transitional-sleigh-beds.txt
# Processing 7686transitional-kids-bedroom-furniture-sets.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/7686transitional-kids-bedroom-furniture-sets.txt
# Processing 9322transitional-folding-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9322transitional-folding-beds.txt
# Processing 9742transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9742transitional-platform-beds.txt
# Processing 7545transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/7545transitional-panel-beds.txt
# Processing 10110transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10110transitional-panel-beds.txt
# Processing 8000transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/8000transitional-panel-beds.txt
# Processing 8540transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/8540transitional-panel-beds.txt
# Processing 9396transitional-loft-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9396transitional-loft-beds.txt
# Processing 2575transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2575transitional-platform-beds.txt
# Processing 9014transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9014transitional-bunk-beds.txt
# Processing 9244transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9244transitional-kids-beds.txt
# Processing 9483transitional-canopy-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9483transitional-canopy-beds.txt
# Processing 9349transitional-murphy-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9349transitional-murphy-beds.txt
# Processing 2590transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2590transitional-platform-beds.txt
# Processing 3561transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3561transitional-platform-beds.txt
# Processing 9582transitional-kids-bedroom-furniture-sets.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9582transitional-kids-bedroom-furniture-sets.txt
# Processing 4876transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/4876transitional-panel-beds.txt
# Processing 8423transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/8423transitional-platform-beds.txt
# Processing 9330transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9330transitional-platform-beds.txt
# Processing 8975transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/8975transitional-platform-beds.txt
# Processing 10263transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10263transitional-platform-beds.txt
# Processing 3124transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3124transitional-platform-beds.txt
# Processing 10123transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10123transitional-panel-beds.txt
# Processing 9940transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9940transitional-panel-beds.txt
# Processing 7722transitional-kids-bedroom-furniture-sets.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/7722transitional-kids-bedroom-furniture-sets.txt
# Processing 2752transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2752transitional-platform-beds.txt
# Processing 9681transitional-loft-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9681transitional-loft-beds.txt
# Processing 9217transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9217transitional-panel-beds.txt
# Processing 9630transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9630transitional-bunk-beds.txt
# Processing 5044transitional-daybeds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/5044transitional-daybeds.txt
# Processing 9923transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9923transitional-panel-beds.txt
# Processing 9635transitional-kids-bedroom-furniture-sets.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9635transitional-kids-bedroom-furniture-sets.txt
# Processing 7770transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/7770transitional-panel-beds.txt
# Processing 10032transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10032transitional-kids-beds.txt
# Processing 9392transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9392transitional-bunk-beds.txt
# Processing 3407transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3407transitional-panel-beds.txt
# Processing 9958transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9958transitional-platform-beds.txt
# Processing 5646transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/5646transitional-kids-beds.txt
# Processing 9407transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9407transitional-platform-beds.txt
# Processing 3024transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3024transitional-platform-beds.txt
# Processing 9410transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9410transitional-bunk-beds.txt
# Processing 5557transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/5557transitional-platform-beds.txt
# Processing 9289transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9289transitional-bunk-beds.txt
# Processing 9259transitional-daybeds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9259transitional-daybeds.txt
# Processing 7754transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/7754transitional-panel-beds.txt
# Processing 2574transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2574transitional-platform-beds.txt
# Processing 9834transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9834transitional-panel-beds.txt
# Processing 10173transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10173transitional-panel-beds.txt
# Processing 5971transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/5971transitional-panel-beds.txt
# Processing 10055transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10055transitional-panel-beds.txt
# Processing 9622transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9622transitional-bunk-beds.txt
# Processing 4863transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/4863transitional-panel-beds.txt
# Processing 9267transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9267transitional-kids-beds.txt
# Processing 10244transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10244transitional-bunk-beds.txt
# Processing 9677transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9677transitional-bunk-beds.txt
# Processing 9567transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9567transitional-bunk-beds.txt
# Processing 9491transitional-loft-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9491transitional-loft-beds.txt
# Processing 9422transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9422transitional-platform-beds.txt
# Processing 8736transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/8736transitional-panel-beds.txt
# Processing 9590transitional-folding-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9590transitional-folding-beds.txt
# Processing 5065transitional-daybeds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/5065transitional-daybeds.txt
# Processing 8507transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/8507transitional-bunk-beds.txt
# Processing 9816transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9816transitional-bunk-beds.txt
# Processing 7594transitional-daybeds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/7594transitional-daybeds.txt
# Processing 9676transitional-loft-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9676transitional-loft-beds.txt
# Processing 9661transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9661transitional-panel-beds.txt
# Processing 5303transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/5303transitional-kids-beds.txt
# Processing 2949transitional-daybeds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2949transitional-daybeds.txt
# Processing 10133transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10133transitional-platform-beds.txt
# Processing 5538transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/5538transitional-panel-beds.txt
# Processing 3063transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3063transitional-panel-beds.txt
# Processing 10124transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10124transitional-panel-beds.txt
# Processing 9415transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9415transitional-kids-beds.txt
# Processing 9547transitional-daybeds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9547transitional-daybeds.txt
# Processing 9507transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9507transitional-bunk-beds.txt
# Processing 5217transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/5217transitional-platform-beds.txt
# Processing 7732transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/7732transitional-bunk-beds.txt
# Processing 10050transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10050transitional-panel-beds.txt
# Processing 3699transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3699transitional-panel-beds.txt
# Processing 2888transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2888transitional-bunk-beds.txt
# Processing 10054transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10054transitional-bunk-beds.txt
# Processing 9782transitional-daybeds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9782transitional-daybeds.txt
# Processing 9924transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9924transitional-platform-beds.txt
# Processing 9451transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9451transitional-bunk-beds.txt
# Processing 10160transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10160transitional-panel-beds.txt
# Processing 9648transitional-sleigh-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9648transitional-sleigh-beds.txt
# Processing 2957transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2957transitional-kids-beds.txt
# Processing 10225transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10225transitional-panel-beds.txt
# Processing 10101transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10101transitional-panel-beds.txt
# Processing 5372transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/5372transitional-platform-beds.txt
# Processing 5888transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/5888transitional-panel-beds.txt
# Processing 9916transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9916transitional-platform-beds.txt
# Processing 4279transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/4279transitional-panel-beds.txt
# Processing 2583transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2583transitional-bunk-beds.txt
# Processing 9581transitional-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9581transitional-beds.txt
# Processing 9985transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9985transitional-platform-beds.txt
# Processing 3216transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3216transitional-panel-beds.txt
# Processing 10305transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10305transitional-panel-beds.txt
# Processing 7590transitional-daybeds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/7590transitional-daybeds.txt
# Processing 9911transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9911transitional-bunk-beds.txt
# Processing 4013transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/4013transitional-platform-beds.txt
# Processing 9595transitional-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9595transitional-beds.txt
# Processing 4968transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/4968transitional-panel-beds.txt
# Processing 9790transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9790transitional-bunk-beds.txt
# Processing 9972transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9972transitional-bunk-beds.txt
# Processing 5190transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/5190transitional-platform-beds.txt
# Processing 9308transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9308transitional-panel-beds.txt
# Processing 10089transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10089transitional-platform-beds.txt
# Processing 8134transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/8134transitional-panel-beds.txt
# Processing 3194transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3194transitional-platform-beds.txt
# Processing 3460transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3460transitional-platform-beds.txt
# Processing 9316transitional-sleigh-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9316transitional-sleigh-beds.txt
# Processing 9544transitional-sleigh-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9544transitional-sleigh-beds.txt
# Processing 5484transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/5484transitional-panel-beds.txt
# Processing 10186transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10186transitional-kids-beds.txt
# Processing 9262transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9262transitional-kids-beds.txt
# Processing 2636transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2636transitional-platform-beds.txt
# Processing 2741transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2741transitional-panel-beds.txt
# Processing 7810transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/7810transitional-platform-beds.txt
# Processing 2555transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2555transitional-platform-beds.txt
# Processing 9174transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9174transitional-panel-beds.txt
# Processing 2607transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2607transitional-platform-beds.txt
# Processing 3474transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3474transitional-panel-beds.txt
# Processing 9905transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9905transitional-bunk-beds.txt
# Processing 4020transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/4020transitional-platform-beds.txt
# Processing 9336transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9336transitional-platform-beds.txt
# Processing 10172transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10172transitional-panel-beds.txt
# Processing 9926transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9926transitional-panel-beds.txt
# Processing 4288transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/4288transitional-platform-beds.txt
# Processing 3353transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3353transitional-panel-beds.txt
# Processing 9467transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9467transitional-panel-beds.txt
# Processing 9957transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9957transitional-bunk-beds.txt
# Processing 10115transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10115transitional-panel-beds.txt
# Processing 8121transitional-daybeds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/8121transitional-daybeds.txt
# Processing 2898transitional-canopy-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2898transitional-canopy-beds.txt
# Processing 9552transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9552transitional-kids-beds.txt
# Processing 5535transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/5535transitional-platform-beds.txt
# Processing 3130transitional-daybeds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3130transitional-daybeds.txt
# Processing 2662transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2662transitional-platform-beds.txt
# Processing 5382transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/5382transitional-platform-beds.txt
# Processing 2821transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2821transitional-kids-beds.txt
# Processing 9869transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9869transitional-platform-beds.txt
# Processing 9650transitional-adjustable-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9650transitional-adjustable-beds.txt
# Processing 2561transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2561transitional-platform-beds.txt
# Processing 7591transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/7591transitional-kids-beds.txt
# Processing 7712transitional-sleigh-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/7712transitional-sleigh-beds.txt
# Processing 9551transitional-daybeds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9551transitional-daybeds.txt
# Processing 9229transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9229transitional-panel-beds.txt
# Processing 5894transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/5894transitional-panel-beds.txt
# Processing 10037transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10037transitional-platform-beds.txt
# Processing 2800transitional-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2800transitional-beds.txt
# Processing 9866transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9866transitional-bunk-beds.txt
# Processing 10279transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10279transitional-bunk-beds.txt
# Processing 9728transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9728transitional-bunk-beds.txt
# Processing 8629transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/8629transitional-panel-beds.txt
# Processing 9603transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9603transitional-bunk-beds.txt
# Processing 3492transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3492transitional-platform-beds.txt
# Processing 5529transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/5529transitional-platform-beds.txt
# Processing 5061transitional-daybeds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/5061transitional-daybeds.txt
# Processing 2548transitional-daybeds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2548transitional-daybeds.txt
# Processing 9253transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9253transitional-panel-beds.txt
# Processing 2848transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2848transitional-bunk-beds.txt
# Processing 9837transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9837transitional-panel-beds.txt
# Processing 2529transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2529transitional-panel-beds.txt
# Processing 9687transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9687transitional-platform-beds.txt
# Processing 9640transitional-kids-bedroom-furniture-sets.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9640transitional-kids-bedroom-furniture-sets.txt
# Processing 9797transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9797transitional-panel-beds.txt
# Processing 9854transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9854transitional-bunk-beds.txt
# Processing 10287transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10287transitional-panel-beds.txt
# Processing 10167transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10167transitional-platform-beds.txt
# Processing 5721transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/5721transitional-panel-beds.txt
# Processing 4000transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/4000transitional-platform-beds.txt
# Processing 8006transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/8006transitional-panel-beds.txt
# Processing 5431transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/5431transitional-panel-beds.txt
# Processing 10228transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10228transitional-panel-beds.txt
# Processing 10099transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/10099transitional-panel-beds.txt
# Processing 2947transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/2947transitional-bunk-beds.txt
# Processing 8484transitional-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/8484transitional-bunk-beds.txt
# Processing 3288transitional-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/3288transitional-panel-beds.txt
# Processing 9529transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9529transitional-kids-beds.txt
# Processing 7576transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/7576transitional-platform-beds.txt
# Processing 9669transitional-sleigh-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9669transitional-sleigh-beds.txt
# Processing 4442transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/4442transitional-platform-beds.txt
# Processing 8510transitional-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/8510transitional-kids-beds.txt
# Processing 9323transitional-daybeds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9323transitional-daybeds.txt
# Processing 9393transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/9393transitional-platform-beds.txt
# Processing 5754transitional-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Transitional/5754transitional-platform-beds.txt
# Processing 3361transitional-daybeds.jpg...
# ...
# Processing 4643modern-toddler-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4643modern-toddler-beds.txt
# Processing 4667modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4667modern-panel-beds.txt
# Processing 4460modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4460modern-panel-beds.txt
# Processing 4792modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4792modern-panel-beds.txt
# Processing 4757modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4757modern-platform-beds.txt
# Processing 4647modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4647modern-platform-beds.txt
# Processing 4702modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4702modern-panel-beds.txt
# Processing 4486modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4486modern-platform-beds.txt
# Processing 4648modern-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4648modern-beds.txt
# Processing 4676modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4676modern-platform-beds.txt
# Processing 4418modern-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4418modern-beds.txt
# Processing 4425modern-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4425modern-beds.txt
# Processing 3031modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/3031modern-panel-beds.txt
# Processing 4801modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4801modern-platform-beds.txt
# Processing 2999modern-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/2999modern-beds.txt
# Processing 4810modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4810modern-panel-beds.txt
# Processing 2512modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/2512modern-platform-beds.txt
# Processing 3075modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/3075modern-panel-beds.txt
# Processing 4685modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4685modern-platform-beds.txt
# Processing 4626modern-folding-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4626modern-folding-beds.txt
# Processing 4527modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4527modern-panel-beds.txt
# Processing 4507modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4507modern-panel-beds.txt
# Processing 4793modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4793modern-panel-beds.txt
# Processing 3147modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/3147modern-platform-beds.txt
# Processing 2918modern-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/2918modern-kids-beds.txt
# Processing 4790modern-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4790modern-kids-beds.txt
# Processing 4714modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4714modern-panel-beds.txt
# Processing 2774modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/2774modern-platform-beds.txt
# Processing 2722modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/2722modern-platform-beds.txt
# Processing 3090modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/3090modern-panel-beds.txt
# Processing 4467modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4467modern-panel-beds.txt
# Processing 4809modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4809modern-panel-beds.txt
# Processing 4624modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4624modern-platform-beds.txt
# Processing 4776modern-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4776modern-bunk-beds.txt
# Processing 4718modern-daybeds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4718modern-daybeds.txt
# Processing 4788modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4788modern-panel-beds.txt
# Processing 4608modern-adjustable-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4608modern-adjustable-beds.txt
# Processing 4452modern-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4452modern-kids-beds.txt
# Processing 3128modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/3128modern-platform-beds.txt
# Processing 4673modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4673modern-platform-beds.txt
# Processing 3279modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/3279modern-platform-beds.txt
# Processing 3002modern-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/3002modern-beds.txt
# Processing 4480modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4480modern-platform-beds.txt
# Processing 2998modern-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/2998modern-beds.txt
# Processing 4562modern-canopy-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4562modern-canopy-beds.txt
# Processing 4579modern-canopy-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4579modern-canopy-beds.txt
# Processing 4481modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4481modern-platform-beds.txt
# Processing 4694modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4694modern-platform-beds.txt
# Processing 4682modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4682modern-panel-beds.txt
# Processing 4735modern-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4735modern-bunk-beds.txt
# Processing 4453modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4453modern-platform-beds.txt
# Processing 4696modern-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4696modern-bunk-beds.txt
# Processing 2664modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/2664modern-platform-beds.txt
# Processing 2599modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/2599modern-platform-beds.txt
# Processing 4491modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4491modern-platform-beds.txt
# Processing 4504modern-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4504modern-beds.txt
# Processing 4634modern-toddler-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4634modern-toddler-beds.txt
# Processing 4787modern-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4787modern-kids-beds.txt
# Processing 4478modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4478modern-platform-beds.txt
# Processing 4584modern-canopy-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4584modern-canopy-beds.txt
# Processing 4695modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4695modern-platform-beds.txt
# Processing 4536modern-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4536modern-beds.txt
# Processing 4618modern-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4618modern-beds.txt
# Processing 4661modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4661modern-platform-beds.txt
# Processing 4466modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4466modern-panel-beds.txt
# Processing 3584modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/3584modern-platform-beds.txt
# Processing 3352modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/3352modern-platform-beds.txt
# Processing 4719modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4719modern-panel-beds.txt
# Processing 4576modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4576modern-panel-beds.txt
# Processing 4533modern-canopy-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4533modern-canopy-beds.txt
# Processing 4606modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4606modern-platform-beds.txt
# Processing 4456modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4456modern-panel-beds.txt
# Processing 4448modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4448modern-platform-beds.txt
# Processing 4604modern-loft-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4604modern-loft-beds.txt
# Processing 2852modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/2852modern-platform-beds.txt
# Processing 4655modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4655modern-platform-beds.txt
# Processing 4591modern-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4591modern-kids-beds.txt
# Processing 3535modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/3535modern-platform-beds.txt
# Processing 4693modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4693modern-platform-beds.txt
# Processing 4741modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4741modern-panel-beds.txt
# Processing 4534modern-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4534modern-bunk-beds.txt
# Processing 4485modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4485modern-panel-beds.txt
# Processing 3046modern-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/3046modern-kids-beds.txt
# Processing 4781modern-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4781modern-bunk-beds.txt
# Processing 4564modern-daybeds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4564modern-daybeds.txt
# Processing 4645modern-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4645modern-beds.txt
# Processing 4727modern-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4727modern-kids-beds.txt
# Processing 4474modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4474modern-panel-beds.txt
# Processing 4744modern-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4744modern-beds.txt
# Processing 4475modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4475modern-panel-beds.txt
# Processing 2673modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/2673modern-platform-beds.txt
# Processing 4699modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4699modern-panel-beds.txt
# Processing 4746modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4746modern-platform-beds.txt
# Processing 4690modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4690modern-panel-beds.txt
# Processing 4521modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4521modern-platform-beds.txt
# Processing 2563modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/2563modern-panel-beds.txt
# Processing 2738modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/2738modern-panel-beds.txt
# Processing 4484modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4484modern-platform-beds.txt
# Processing 2770modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/2770modern-platform-beds.txt
# Processing 4502modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4502modern-platform-beds.txt
# Processing 4577modern-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4577modern-kids-beds.txt
# Processing 4588modern-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4588modern-kids-beds.txt
# Processing 4093modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4093modern-panel-beds.txt
# Processing 4749modern-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4749modern-bunk-beds.txt
# Processing 4539modern-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4539modern-bunk-beds.txt
# Processing 4680modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4680modern-panel-beds.txt
# Processing 4602modern-loft-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4602modern-loft-beds.txt
# Processing 2952modern-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/2952modern-kids-beds.txt
# Processing 4629modern-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4629modern-kids-beds.txt
# Processing 4796modern-daybeds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4796modern-daybeds.txt
# Processing 4455modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4455modern-panel-beds.txt
# Processing 4513modern-canopy-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4513modern-canopy-beds.txt
# Processing 4583modern-loft-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4583modern-loft-beds.txt
# Processing 2853modern-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/2853modern-beds.txt
# Processing 2633modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/2633modern-platform-beds.txt
# Processing 3038modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/3038modern-platform-beds.txt
# Processing 4514modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4514modern-platform-beds.txt
# Processing 2596modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/2596modern-platform-beds.txt
# Processing 4739modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4739modern-panel-beds.txt
# Processing 3993modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/3993modern-platform-beds.txt
# Processing 4794modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4794modern-panel-beds.txt
# Processing 4470modern-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4470modern-bunk-beds.txt
# Processing 3000modern-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/3000modern-beds.txt
# Processing 4734modern-bunk-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4734modern-bunk-beds.txt
# Processing 4492modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4492modern-panel-beds.txt
# Processing 4802modern-kids-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4802modern-kids-beds.txt
# Processing 2546modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/2546modern-platform-beds.txt
# Processing 4745modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4745modern-platform-beds.txt
# Processing 4668modern-panel-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4668modern-panel-beds.txt
# Processing 2749modern-platform-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/2749modern-platform-beds.txt
# Processing 4552modern-beds.jpg...
# Saved YOLO format text to: /content/output/beds/Modern/4552modern-beds.txt
# Processing 4638modern-panel-beds.jpg...

# %%
import os
import cv2
import matplotlib.pyplot as plt

def draw_bounding_box_center(image_path, bounding_boxes):
    # Load the image
    image = cv2.imread(image_path)
    if image is None:
        print(f"Failed to load image: {image_path}")
        return

    # Convert BGR to RGB for display
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Get image dimensions
    height, width, _ = image.shape

    for bounding_box in bounding_boxes:
        # Extract and convert normalized coordinates to pixel coordinates
        cx = int(bounding_box[0] * width)
        cy = int(bounding_box[1] * height)
        w = int(bounding_box[2] * width)
        h = int(bounding_box[3] * height)

        # Calculate the corners of the bounding box
        x_min = cx - w // 2
        y_min = cy - h // 2
        x_max = cx + w // 2
        y_max = cy + h // 2

        # Draw the bounding box
        cv2.rectangle(image, (x_min, y_min), (x_max, y_max), color=(255, 0, 0), thickness=2)

    # Display the image
    plt.figure(figsize=(10, 6))
    plt.imshow(image)
    plt.axis("off")
    plt.show()

def read_yolo_txt(file_path):
    bounding_boxes = []
    try:
        with open(file_path, "r") as file:
            for line in file:
                parts = line.strip().split()
                if len(parts) == 5:  # YOLO format: <class_id> <cx> <cy> <width> <height>
                    cx, cy, width, height = map(float, parts[1:])
                    bounding_boxes.append([cx, cy, width, height])
    except FileNotFoundError:
        print(f"Text file not found: {file_path}")
    return bounding_boxes

# Example usage
image_path = "/content/output/Bonn_Furniture_Styles_Dataset/houzz/beds/Asian/19726asian-daybeds.jpg"
txt_path = "/content/output/beds/Asian/19726asian-daybeds.txt"

# Read bounding boxes from the YOLO format text file
bounding_boxes = read_yolo_txt(txt_path)

# Draw the bounding boxes on the image
if bounding_boxes:
    draw_bounding_box_center(image_path, bounding_boxes)
else:
    print("No bounding boxes to draw.")

# %%
import os

# YOLO 텍스트 데이터를 그대로 저장
def yolo_to_txt(boxes, phrases, class_names):
    yolo_data = []
    for idx, box in enumerate(boxes):
        # Extract class name and find its ID
        class_name = phrases[idx]
        class_id = class_names.index(class_name) if class_name in class_names else -1

        # Only include valid class IDs
        if class_id != -1:
            # Directly use the bounding box in YOLO format
            x_center, y_center, width, height = map(float, box)
            yolo_data.append(f"{class_id} {x_center:.6f} {y_center:.6f} {width:.6f} {height:.6f}")
    return yolo_data

# 이미지 처리 함수
def process_images(input_dir, output_dir, model, text_prompt, box_threshold, text_threshold, class_names):
    os.makedirs(output_dir, exist_ok=True)  # 출력 디렉토리 생성

    for root, _, files in os.walk(input_dir):
        for file_name in files:
            if file_name.lower().endswith(('.jpg', '.png', '.jpeg')):  # 이미지 파일 필터링
                image_path = os.path.join(root, file_name)
                print(f"Processing {file_name}...")

                # 이미지 로드
                image_source, image = load_image(image_path)

                # Grounding DINO 모델로 예측
                boxes, logits, phrases = predict(
                    model=model,
                    image=image,
                    caption=text_prompt,
                    box_threshold=box_threshold,
                    text_threshold=text_threshold
                )

                # Grounding DINO의 YOLO 좌표와 라벨 그대로 사용
                yolo_output = yolo_to_txt(boxes, phrases, class_names)

                # YOLO 텍스트 파일 저장
                relative_path = os.path.relpath(root, input_dir)  # 하위 폴더 구조 유지
                output_subdir = os.path.join(output_dir, relative_path)
                os.makedirs(output_subdir, exist_ok=True)  # 출력 하위 폴더 생성

                txt_file_name = f"{os.path.splitext(file_name)[0]}.txt"
                txt_path = os.path.join(output_subdir, txt_file_name)
                with open(txt_path, "w") as txt_file:
                    txt_file.write("\n".join(yolo_output))
                print(f"Saved YOLO format text to: {txt_path}")

# 경로 설정
INPUT_DIR = "/content/output/Bonn_Furniture_Styles_Dataset/houzz/chairs"
OUTPUT_DIR = "/content/output/beds"
TEXT_PROMPT = "chair"
BOX_THRESHOLD = 0.35
TEXT_THRESHOLD = 0.25

# 클래스 이름 정의
class_names = ['bed', 'chair', 'dresser', 'lamp', 'sofa', 'table']

# 실행
process_images(
    input_dir=INPUT_DIR,
    output_dir=OUTPUT_DIR,
    model=model,
    text_prompt=TEXT_PROMPT,
    box_threshold=BOX_THRESHOLD,
    text_threshold=TEXT_THRESHOLD,
    class_names=class_names
)
